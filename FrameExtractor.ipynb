# %% [markdown]
# <a href="https://colab.research.google.com/github/bioimagehuji/frame_extractor/blob/main/FrameExtractor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# FrameExtractor is a script to take a google drive folder as input, look for all MTS video files, then create a sub folder for each file, each subfolder will have screenshots of a frame from the video. FrameExtractor extracts one screenshot per second named 0001,0002 etc.

# %% [markdown]
# > Step 1: Mount google drive. you can do it here:
# ![Screenshot_20230122_234028_Chrome.jpg](data:image/jpeg;base64,...)
#
#
# in mobile: selet "show file browser" in menu and look for the above screenshot.

# %% [markdown]
# > Step 2: Browse and find the folder with the videos, and Copy its path:
# ![Screenshot_20230123_000742_Chrome.jpg](data:image/jpeg;base64,...)

# %%
#@title Step 3: Paste  folder path and run
input_folder = "/content/drive/MyDrive/mask127 mask136 mask137"  #@param {type:"string"}
# !apt-get install -y ffmpeg
import os
folder_path = input_folder +"/"
for file in os.listdir(folder_path):
    if file.endswith(".MTS"):
                filename = os.path.splitext(file)[0]
                output_folder = folder_path + filename
                if not os.path.exists(output_folder):
                  os.makedirs(output_folder)
                  output_path = os.path.join(output_folder, "%04d.png")
                  # !ffmpeg -i "$folder_path/$file" -vf fps=1 "$output_path"
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...
